# %% [markdown]
# <a href="https://colab.research.google.com/github/rajv33rbhosal3/PYTHON/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-f425ed98-f652-4f74-bda7-40e1ba7dde01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f425ed98-f652-4f74-bda7-40e1ba7dde01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sqlite3
db = 'database.sqlite'
conn = sqlite3.connect(db)
print("Opened data successfully")
# Out:
# Opened data successfully

# %%
import pandas as pd
table = pd.read_sql("""SELECT * FROM sqlite_master WHERE type='table';""", conn)
table
# Out:
# Empty DataFrame
# Columns: [type, name, tbl_name, rootpage, sql]
# Index: []

# %%
matches = pd.read_sql("""SELECT * FROM Match;""", conn)
matches.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: Match
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-12-3056948950f5> in <cell line: 1>()
# ----> 1 matches = pd.read_sql("""SELECT * FROM Match;""", conn)
#       2 matches.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
# ...

# %%
res1 = pd.read_sql("""SELECT AVG(Win_Margin), Match_Winner FROM Match WHERE Season_Id == 9 GROUP BY Match_Winner ORDER BY AVG(Win_Margin);""", conn)
res1

# %%
res2 = pd.read_sql("""SELECT COUNT(DISTINCT Venue_id) FROM Match WHERE Season_Id == 9;""", conn)
res2
